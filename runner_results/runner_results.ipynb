# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/Rex/vscode/ai_llm_optimization/runner_results/eval_once.csv')

# %%
df.head()
# Out:
#    idx  temperature  top_p  pred  \
# 0    0          0.0    1.0     2
# 1    1          0.0    1.0     1
# 2    2          0.0    1.0     3
# 3    3          0.0    1.0     1
# 4    4          0.0    1.0     2
#
#                                             question  \
# 0  The cyclic subgroup of Z_24 generated by 18 ha...
# 1        Find the order of the factor group Z_6/<3>.
# 2  Statement 1 | A permutation that is a product ...
# 3  Find the order of the factor group (Z_4 x Z_12...
# 4  Find the maximum possible order for some eleme...
#
#                                              choices  ground_truth  \
# 0                              ['4', '8', '12', '6']             0
# 1                              ['2', '3', '6', '12']             1
# 2  ['True, True', 'False, False', 'True, False', ...             0
# 3                              ['2', '3', '4', '12']             2
# 4                             ['4', '6', '12', '24']             2
#
# ...
